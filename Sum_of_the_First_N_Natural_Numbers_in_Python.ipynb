# %% [markdown]
# <a href="https://colab.research.google.com/github/SAMYUKTHAYEDLA/BASIC-PROGRAMS/blob/main/Sum_of_the_First_N_Natural_Numbers_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("enter the number"))
sum = 0
for i in range(num+1):
   sum+=i
print(sum)
# Out:
# enter the number5
# 15
